# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 8</b></center>
# <center><b><h3>Roll No : 453</b></center>
# <center><b><h3>Name : Savaliya Dhruvi B.</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to find their union, intersection, and difference of the given two sets.
# **Sample Input:**
# ```
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
#
# ```
# **Sample Output:**
# ```
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference (A-B): {1, 2}
#
# ```

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print('Union: ',A|B)
print('Intersection: ',A&B)
print('Difference (A-B): ',A-B)
# Out:
# Union:  {1, 2, 3, 4, 5, 6}
# Intersection:  {3, 4}
# Difference (A-B):  {1, 2}

# %% [markdown]
# ### 02) WAP to Find elements common to all three given sets.
# **Sample Input:**
# ```
# A = {1, 2, 3, 4}
# B = {2, 3, 5}
# C = {2, 3, 6}
#
# ```
# **Sample Output:**
# ```
# {2, 3}
# ```

# %%
A = {1, 2, 3, 4}
B = {2, 3, 5}
C = {2, 3, 6}
print(A&B&C)
# Out:
# {2, 3}

# %% [markdown]
# ### 03) WAP to remove duplicate elements from a list while preserving unique values.
# **Sample Input:**
# ```
# [10, 20, 10, 30, 20, 40]
#
# ```
# **Sample Output:**
# ```
# {10, 20, 30, 40}
# ```

# %%
li = [10, 20, 10, 30, 20, 40]
res = []
for i in li:
    if i not in res:
        res.append(i)
print(set(res))
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ### 04) WAP to count how many elements are common between two sets.
#
# **Sample Input:**
# ```
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
# ```
# **Sample Output:**
# ```
# 2
# ```

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
res = [A-B]
count = 1
for i in res:
    count+=1
print(count)
# Out:
# 2

# %% [markdown]
# ### 05) WAP to Merge two dictionaries. If a key exists in both dictionaries, add their values.
#
# **Sample Input:**
# ```
# Dict1 = {1: 10, 2: 20, 3: 30}
# Dict2 = {2: 40, 3: 50, 4: 60}
#
# ```
# **Sample Output:**
# ```
# {1: 10, 2: 60, 3: 80, 4: 60}
# ```

# %%
Dict1 = {1: 10, 2: 20, 3: 30}
Dict2 = {2: 40, 3: 50, 4: 60}
merged_Dict = {}
for key in Dict1:
    merged_Dict[key] = Dict1[key]
for key in Dict2:
    if key in merged_Dict:
        merged_Dict[key]+=Dict2[key]
    else:
        merged_Dict[key] = Dict2[key]
print(merged_Dict)
# Out:
# {1: 10, 2: 60, 3: 80, 4: 60}

# %% [markdown]
# ### 06) WAP to Sort a dictionary in ascending order of its values.
# Hint: in sorted(), use udf for key parameter
#
#
# **Sample Input:**
# ```
# {'Math': 70, 'Physics': 85, 'Chemistry': 60}
#
# ```
# **Sample Output:**
# ```
# {'Chemistry': 60, 'Math': 70, 'Physics': 85}
# ```

# %%
d1 = {'Math': 70, 'Physics': 85, 'Chemistry': 60}
sorted_key = (dict(sorted(d1.items())))
print(sorted_key)
# Out:
# {'Chemistry': 60, 'Math': 70, 'Physics': 85}

# %% [markdown]
# ### 07) WAP to find the keys having maximum and minimum values in a dictionary.
#
# **Sample Input:**
# ```
# {'A': 50, 'B': 90, 'C': 30}
# ```
# **Sample Output:**
# ```
# Max Value Key: B
# Min Value Key: C
#
# ```

# %%
d = {'A': 50, 'B': 90, 'C': 30}
max_key = min_key = list(d.keys())[0]

for key in d:
    if d[key] > d[max_key]:
        max_key = key
    if d[key] < d[min_key]:
        min_key = key      

print("Key with maximum value:", max_key)
print("Key with minimum value:", min_key)
# Out:
# Key with maximum value: B
# Key with minimum value: C

# %% [markdown]
# ### 08) WAP to create a dictionary with numbers from 1 to N as keys and their squares as values.
#
# **Sample Input:**
# ```
# N = 5
# ```
# **Sample Output:**
# ```
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# ```

# %%
N = 5
d = {}
res = {i:i**2 for i in range(1,N+1)}
print(res)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### 09) WAP to count the frequency of each character in a string using a dictionary.
# **Sample Input:**
# ```
# programming
# ```
# **Sample Output:**
# ```
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}
# ```

# %%
s = 'programming'
freq = {}
# for ch in s:
#     if ch in freq:
#         freq[ch] += 1
#     else:
#          freq[ch]= 1
# print(freq)
#or
for ch in s:
    freq[ch] = freq.get(ch,0)+1
print(freq)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %% [markdown]
# ### 10) WAP to swap keys and values of a dictionary.
# **Sample Input:**
# ```
# {1: 'A', 2: 'B', 3: 'C'}
# ```
# **Sample Output:**
# ```
# {'A': 1, 'B': 2, 'C': 3}
# ```

# %%
d1 = {1: 'A', 2: 'B', 3: 'C'}
d2 = {}
for k,v in d1.items():
    d2[v] = k
print(d2)

#or we can not write like that
# d1 = {1: 'A', 2: 'B', 3: 'C'}
# for k,v in d1.items():
#     d1[v] = k
# print(d1)
# Although dictionaries are mutable, Python does not allow adding or removing keys while iterating over a dictionary because 
# it changes the dictionary size during iteration.

# What exactly goes wrong?
# d1.items() starts iterating over keys: 1, 2, 3
# Inside the loop you add new keys: 'A', 'B', 'C'
# Dictionary size changes
# Python raises:
# RuntimeError: dictionary changed size during iteration
# Out:
# {'A': 1, 'B': 2, 'C': 3}

# %% [markdown]
# ### 11) WAP to find the student with the highest total marks, given student names and their marks.
#
# **Sample Input:**
# ```
# {'Amit': [70, 80, 90], 'Riya': [85, 75, 80], 'Neha': [60, 70, 65]}
# ```
# **Sample Output:**
# ```
# Topper: Amit
# ```

# %%
d = {'Amit': [70, 80, 90], 'Riya': [85, 75, 80], 'Neha': [60, 70, 65]}
topper = None
max_total = 0
for key in d:
    total = sum(d[key])
    if(total > max_total):
        max_total = total
        topper = key
print('Topper:',topper)
# Out:
# Topper: Amit

# %% [markdown]
# ### 12) WAP to extract keys whose values are even numbers.
#
# **Sample Input:**
# ```
# {1: 11, 2: 20, 3: 15, 4: 40}
# ```
# **Sample Output:**
# ```
# [2, 4]
# ```

# %%
d = {1: 11, 2: 20, 3: 15, 4: 40}
res = []
for key in d:
    if key % 2 == 0:
        res.append(key)
print(res)
# Out:
# [2, 4]

# %% [markdown]
# ### 13) WAP to Find common keys between two dictionaries.
#
# **Sample Input:**
# ```
# Dict1 = {1: 'A', 2: 'B', 3: 'C'}
# Dict2 = {2: 'X', 3: 'Y', 4: 'Z'}
#
# ```
# **Sample Output:**
# ```
# [2, 3]
# ```

# %%
d1 = {1: 'A', 2: 'B', 3: 'C'}
d2 = {2: 'X', 3: 'Y', 4: 'Z'}
res = []
for key in d1:
     if key in d2:
         res.append(key)
print(res)
# Out:
# [2, 3]

# %% [markdown]
# ### 14) WAP to handle missing keys in dictionaries.
#
# **Sample Input - 1:**
# ```
# dict1 = {'a': 5, 'c': 8, 'e': 2}
# key = 'c'
# ```
# **Sample Output - 1:**
# ```
# 8
# ```
#
# **Sample Input - 2:**
# ```
# dict1 = {'a': 5, 'c': 8, 'e': 2}
# key = 'd'
# ```
# **Sample Output - 2:**
# ```
# Key Not Found
# ```

# %%
d1 = {'a': 5, 'c': 8, 'e': 2}
k = 'd'
flag = 1
for key in d1:
    if key in k:
        flag = 1
        break;
    else:
        flag = 0
if(flag):
    print(d1[key])
else:
    print("Key Not Found")
# Out:
# Key Not Found

# %% [markdown]
# ### 15) WAP to create a dictionary using dictionary comprehension from two lists containing student names and marks. Include only those students in the dictionary whose marks are greater than or equal to 75.
#
# **Sample Input:**
# ```
# students = ['Amit', 'Riya', 'Neha', 'Karan']
# marks = [78, 72, 85, 60]
# ```
# **Sample Output:**
# ```
# {'Amit': 78, 'Neha': 85}
# ```

# %%
students = ['Amit', 'Riya', 'Neha', 'Karan']
marks = [78, 72, 85, 60]
d = {student:mark for student,mark in zip(students,marks) if mark >= 75} 
d
# Out:
# {'Amit': 78, 'Neha': 85}
