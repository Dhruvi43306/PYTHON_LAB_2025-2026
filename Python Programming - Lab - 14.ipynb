# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h3>Roll No.:453</b></center>
# <center><b><h3>Name:Savaliya Dhruvi B.</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import cal
a = cal.add(1,2)
print("Addition:",a)

b = cal.diffrence(1,2)
print("Diffrence:",b)

c = cal.multipecation(1,2)
print("multipecation:",c)

d = cal.division(1,2)
print("Division:",d)
# Out:
# Addition: 3
# Diffrence: -1
# multipecation: 2
# Division: 0.5

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
string = "Dhruvi"
import random
random.choice(string)
# Out:
# 'D'

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
li = [1,2,3,4]
random.choice(li)
# Out:
# 2

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
random.seed(1)
rn = random.randint(1,6)
print(rn)
# Out:
# 2

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
li = []
for i in range(100,1000,5):
    li.append(i)
a = random.choices(li,k=3)
print(a)
# Out:
# [610, 820, 155]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
# li = [[1],[1]]
# print(id(li[0]))
# print(id(li[1]))
# print("------------------")
# for i in range(1,101):
#      x = random.randint(100,999)
#      li.append(x)
# print(a[0])
# print(a[1])    
# a = [random.choice(li)]
# a.append(random.choice(li))
# print(a)
# print(id(a[0]))
# print(id(a[1]))

import random

li = set()

while len(li) < 101:
    li.add(random.randint(100, 999))

li = list(li)

a = random.sample(li, k=2)

print(f"Winner number of lottery ticket is {a[0]}")
print(f"Runner up number of lottery ticket is {a[1]}")
# Out:
# Winner number of lottery ticket is 895
# Runner up number of lottery ticket is 154

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-03-02 12:52:14.862998

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
td = datetime.date.today()
print(td+datetime.timedelta(days = -7))
# Out:
# 2026-02-23

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
t1 = datetime.date.today()
t2 = td+datetime.timedelta(days = -7)
print(t1 - t2)
# Out:
# 7 days, 0:00:00

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
import datetime
t1 = datetime.date.today()
t2 = t1.strftime("%A")
print(type(t2))
print(t2)
# print(type(t1))
# Out:
# <class 'str'>
# Monday
