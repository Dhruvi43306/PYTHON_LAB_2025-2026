# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
a = int(input("Enter a Number:"));

if(a > 0):
    print(f"{a} is a Positive.");
else:
    print(f"{a} is a Negative.");
# Out:
# Enter a Number: -5
# -5 is Negative.

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
a = int(input("Enter a Number:"));

if(a % 2 == 0):
    print(f"{a} is a Even Number.");
else:
    print(f"{a} is a Odd Number.");
# Out:
# Enter a Number: 2
# 2 is a Even Number.

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
a,b = input("Enter a Number:").split(" ");
a = int(a);
b = int(b);
#if(a > b):
    #print(f"{b} is a greater then {a}.");
#if(a < b):
    #print(f"{a} is a lesser then {b}.");

#Using Ternary Oprater:
res = a if a > b else b
print(f"{res} is Greater.");
# Out:
# Enter a Number: 10 20
# 20

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
a,b,c = input("Enter a Number:").split(" ");
a = int(a);
b = int(b);
c = int(c);
##if(a > b and a > c):
    ##print(f"The number {a} is Greater.");
##elif(b > c and b > a):
    ##print(f"The number {b} is Greater.");
##else:
   ## print(f"The number {c} is Greater.");

##using Ternary Oprater:
res = a if a>b and a>c else (b if b>c else c)
print(f"{res} is Greater.");
# Out:
# Enter a Number: 5 10 15
# 15 is Greater.

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# #### [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year = int(input("Enter a Year:"))
if((year % 4 == 0 and year % 100 != 0)or year % 400 == 0):
    print(f"{year} is Leap Year.")
else:
    print(f"{year} is Not Leap Year.")
# Out:
# Enter a Year: 2025
# 2025 is Not Leap Year.

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
no_of_day = int(input("Enter a Number of Days."))
match no_of_day:
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wenesday")
    case 4:
        print("Thirsday")
    case 5:
        print("Friday")
    case 6:
        print("Saturday")
    case 7:
        print("Sunday")
    case _:
        print("PLZ Enter Valid no_of_days!!")
# Out:
# Enter a Number of Days. 8
# PLZ Enter Valid no_of_days!!

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %% [markdown]
# a,b,op = input("Enter a Number:").split(" ");
# a = int(a);
# b = int(b);
# match op:
#     case '+':
#         print(f"Sum:",{a+b});
#     case '-':
#         print(f":Substraction",{a-b});
#     case '*':
#         print(f"Multiplication:",{a*b});
#     case '/':
#         if(b != 0):
#             print(f"Number is Divisible:{a/b}")
#         else:
#             print("Number is Not Divisible.")
#     case _:
#         print("Invalid Number!");

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# ### Fail below 35
# ### Pass Class between 35 to 45
# ### Second Class
# ### between 45 to 60
# ### First Class between 60 to 70
# ### Distinction if more than 70

# %%
sub1,sub2,sub3,sub4,sub5 = input("Enter a 5 Subject of Marks:").split(" ");
sub1 = int(sub1);
sub2 = int(sub2);
sub3 = int(sub3);
sub4 = int(sub4);
sub5 = int(sub5);

sum = sub1 + sub2 + sub3 + sub4 + sub5
Percentage = float(sum) / 5

if(Percentage >= 70):
    print("Distinction")
elif( Percentage >= 60):
    print("First Class")
elif( Percentage >= 45):
    print("Second Class")
elif(Percentage >= 35):
    print("Pass Class")
else:
    print("Fail")
# Out:
# Enter a 5 Subject of Marks: 50 50 50 50 50
# Second Class

# %% [markdown]
# ### 09) WAP to find the second largest number among three user input numbers.

# %%
a,b,c = input("Enter a Number:").split(" ");
a = int(a);
b = int(b);
c = int(c);
max = a if a > b and a > c else(b if b > c else c) 
if max == a:
    second = b if b > c else c
elif max == b:
    second = a if a > c else c
else:
    second = a if a > b else b
print("Second largest number is:", second)
# Out:
# Enter a Number: 5 10 15
# Second largest number is: 10

# %% [markdown]
# ### 10) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# #### a. First 1 to 50 units – Rs. 2.60/unit
# #### b. Next 50 to 100 units – Rs. 3.25/unit
# #### c. Next 100 to 200 units – Rs. 5.26/unit
# #### d. above 200 units – Rs. 8.45/unit

# %%
 unit = int(input("Enter Unit:"))
if(unit >= 1 and unit <= 50):
    print(f"Price: {unit*2.60}")
elif(unit <= 100):
    print(f"Price:{50*2.60+((unit-50)*3.25)}")
elif(unit <= 200):
    print(f"Price:{50*2.60+((unit-50)*3.25)+((unit-100)*5.26)}")
else:
    print(f"Price:{50*2.60+((unit-50)*3.25)+((unit-100)*5.26)+((unit-200)*8.45)}")
# Out:
# Enter Unit: 125
# Price:505.25
