# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 9</b></center>
# <center><b><h3>Roll No : 453</b></center>
# <center><b><h3>Name : Savaliya Dhruvi B.</b></center>
# <pre>

# %% [markdown]
# ### 01) Write a function to calculate BMI given mass and height. (BMI = mass/h**2)

# %%
def calculate_BMI(mass,h):
    BMI = mass/h**2
    print("BMI = ",BMI)
calculate_BMI(1,1)
# Out:
# BMI =  1.0

# %% [markdown]
# ### 02) Write a function that add first n numbers.

# %%
def Number(n):
    sum1 = 0
    sum1 = n*(n+1)/2
    print(sum1)
Number(5)
# Out:
# 15.0

# %% [markdown]
# ### 03) Write a function that returns 1 if the given number is Prime or 0 otherwise.

# %%
def prime(n):
    for i in range(1,n+1):
        if(n%i == 0):
            return 1
        else:
            return 0
prime(13)
# Out:
# 1

# %% [markdown]
# ### 04) Write a function that returns the list of Prime numbers between given two numbers.

# %%
def PrimeRange(a, b):
    li = []
    for i in range(a, b+1):
        if i > 1:
            flag = 0
            for j in range(2, i):
                if i % j == 0:
                    flag = 1
                    break
            if flag == 0:
                li.append(i)
    return li

print(PrimeRange(4, 10))
# Out:
# [5, 7]

# %% [markdown]
# ### 05) Write a function that returns True if the given string is Palindrome or False otherwise.

# %%
def Palingdrome(x):
    if x == x[::-1]:
        return True
    else:
        return False
Palingdrome("aba")
# Out:
# True

# %% [markdown]
# ### 06) Write a function that returns the sum of all the elements of the list.

# %%
def sumList(list):
    sum1 = 0
    for i in li:
        sum1 += i
    print(sum1)
sumList([1,2,3,4])
# Out:
# 10

# %% [markdown]
# ### 07) Write a function to calculate the sum of the first element of each tuples inside the list.

# %%
def sumTuple(li):
    sum1 = 0
    for i in li:
        sum1 += i[0]
    print(sum1)    
sumTuple([(1,2),(2,3)])
# Out:
# 3

# %% [markdown]
# ### 08) Write a recursive function to find nth term of Fibonacci Series.

# %%
def fibonaci(n):
    if n == 0:
        return 0;
    elif n == 1:
        return 1
    else:
        return fibonaci(n-1) + fibonaci(n-2)
n = int(input("Enter value of n: "))
print("Nth Fibonacci term is:")
for i in range(n):
    print(fibonaci(i),end = " ")
# Out:
# Enter value of n:  5
# Nth Fibonacci term is:
# 0 1 1 2 3

# %% [markdown]
# ### 09) Write a function to get the name of the student based on the given rollno.
# #### Example: Given dict1 = {101:'Ajay', 102:'Rahul', 103:'Jay', 104:'Pooja'} find name of student whose rollno = 103

# %%
dict1 = {101:'Ajay', 102:'Rahul', 103:'Jay', 104:'Pooja'}
def studentRoll(rollNo):
    for roll,name in dict1.items():
        if roll == rollNo:
            print(name)
studentRoll(103)
# Out:
# Jay

# %% [markdown]
# ### 10) Write a function to get the sum of the scores ending with zero.
# #### Example : scores = [200, 456, 300, 100, 234, 678]
# #### Ans = 200 + 300 + 100 = 600

# %%
scores = [200, 456, 300, 100, 234, 678]

def scoreEndingZero(scores):
    sum1 = 0
    for i in scores:
        if i % 10 == 0:
            sum1 += i
    print(sum1)
scoreEndingZero(scores)
# Out:
# 600

# %% [markdown]
# ### 11) Write a function to invert a given Dictionary.
# #### hint: keys to values & values to keys
# #### Before : {'a': 10, 'b':20, 'c':30, 'd':40}
# #### After : {10:'a', 20:'b', 30:'c', 40:'d'}

# %%
li = {'a': 10, 'b':20, 'c':30, 'd':40}
l1 = {}
def invertDictionary(li):
    for k,v in li.items():
        l1[v] = k
    print(l1)
invertDictionary(li)
# Out:
# {10: 'a', 20: 'b', 30: 'c', 40: 'd'}

# %% [markdown]
# ### 12) Write a function that returns the number of uppercase and lowercase letters in the given string.
# #### example : Input : s1 = AbcDEfgh ,Ouptput : no_upper = 3, no_lower = 5

# %%
def upper_lower(s1):
    no_upper = 0
    no_lower = 0
    for i in s1:
        if i.isupper():
           no_upper+=1
        else:
            no_lower+=1
    print("no_upper:",no_upper)       
    print("no_lower:",no_lower)
upper_lower('AbcDEfgh')
# Out:
# no_upper: 3
# no_lower: 5

# %% [markdown]
# ### 13) Write a lambda function to get smallest number from the given two numbers.

# %%
no = lambda a , b: a if a< b else b
no(5,2)
# Out:
# 2

# %% [markdown]
# ### 14) For the given list of names of students, extract the names having more that 7 characters. Use filter().

# %%
name = list(filter(lambda a: len(a)>7,['dharmishtha','dhruvi']))
print(name)
# Out:
# ['dharmishtha']

# %% [markdown]
# ### 15) For the given list of names of students, convert the first letter of all the names into uppercase. use map().

# %%
def covertFirstCapital(li):
    return li[0].upper() + li[1:]
name  = list(map(covertFirstCapital,['dharmishtha','dhruvi']))
print(name)
# Out:
# ['Dharmishtha', 'Dhruvi']

# %% [markdown]
# ### 16) Write udfs to call the functions with following types of arguments:
# 1. Positional Arguments
# 2. Keyword Arguments
# 3. Default Arguments
# 4. Variable Legngth Positional(*args) & variable length Keyword Arguments (**kwargs)
# 5. Keyword-Only & Positional Only Arguments

# %%
def posinationalArgs(a,b):
    print(a,b)
posinationalArgs(2,3)
def keywordArgs(a,b):
    print(a,b)    
keywordArgs(a=4,b=3)
def defaultArgs(a,b = 0):
    print(a,b)
defaultArgs('gbg')
t1 = 1,2,3,4
def variableLength(*t1):
    print(t1)
variableLength(1)
# Out:
# 2 3
# 4 3
# gbg 0
# (1,)
